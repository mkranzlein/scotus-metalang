# %% [markdown]
# I sourced data from CAP based on super-scotus docket numbers. Do these docket numbers match up with scdb?

# %%
# %cd -q ../..

# %%
import jsonlines
from collections import Counter, defaultdict

import pandas as pd

# %%
convokit = []
with open("data/convokit/cases.jsonl", "r") as f:
    reader = jsonlines.Reader(f)
    for row in reader:
        if row["year"] >= 1986:
            convokit.append(row)

# %%
convokit[0]
# Out:
# {'id': '1986_84-2022',
#  'year': 1986,
#  'citation': '479 US 335',
#  'title': '324 Liquor Corporation v. Duffy',
#  'petitioner': '324 Liquor Corporation',
#  'respondent': 'Duffy',
#  'docket_no': '84-2022',
#  'court': 'Rehnquist Court',
#  'decided_date': 'Jan 13, 1987',
#  'url': 'https://www.oyez.org/cases/1986/84-2022',
#  'transcripts': [{'name': 'Oral Argument - November 03, 1986',
#    'url': 'https://apps.oyez.org/player/#/rehnquist1/oral_argument_audio/19212',
#    'id': 19212,
#    'case_id': '1986_84-2022'}],
#  'adv_sides_inferred': False,
#  'known_respondent_adv': True,
#  'advocates': {'W. Stephen Cannon': {'id': 'w_stephen_cannon',
#    'name': 'W. Stephen Cannon',
#    'role': 'on behalf of the United States as amicus curiae supporting appellant',
#    'side': 2},
#   'Bertram K. Kantor': {'id': 'bertram_k_kantor',
#    'name': 'Bertram K. Kantor',
#    'role': 'on behalf of the appellant',
#    'side': 1},
#   'Christopher Keith Hall': {'id': 'christopher_keith_hall',
#    'name': 'Christopher Keith Hall',
#    'role': 'on behalf of the appellees',
#    'side': 0},
#   'Bertram M. Kantor': {'id': 'bertram_m_kantor',
#    'name': 'Bertram M. Kantor',
#    'role': 'for the appellant',
#    'side': 1}},
#  'win_side': 1.0,
#  'win_side_detail': 4.0,
#  'scdb_docket_id': '1986-019-01',
#  'votes': {'j__thurgood_marshall': 2.0,
#   'j__william_j_brennan_jr': 2.0,
#   'j__byron_r_white': 2.0,
#   'j__harry_a_blackmun': 2.0,
#   'j__lewis_f_powell_jr': 2.0,
#   'j__william_h_rehnquist': 1.0,
#   'j__john_paul_stevens': 2.0,
#   'j__sandra_day_oconnor': 1.0,
#   'j__antonin_scalia': 2.0},
#  'votes_detail': {'j__thurgood_marshall': 1.0,
#   'j__william_j_brennan_jr': 1.0,
#   'j__byron_r_white': 1.0,
#   'j__harry_a_blackmun': 1.0,
#   'j__lewis_f_powell_jr': 1.0,
#   'j__william_h_rehnquist': 2.0,
#   'j__john_paul_stevens': 1.0,
#   'j__sandra_day_oconnor': 2.0,
#   'j__antonin_scalia': 1.0},
#  'is_eq_divided': False,
#  'votes_side': {'j__thurgood_marshall': 1.0,
#   'j__william_j_brennan_jr': 1.0,
#   'j__byron_r_white': 1.0,
#   'j__harry_a_blackmun': 1.0,
#   'j__lewis_f_powell_jr': 1.0,
#   'j__william_h_rehnquist': 0.0,
#   'j__john_paul_stevens': 1.0,
#   'j__sandra_day_oconnor': 0.0,
#   'j__antonin_scalia': 1.0}}

# %%
convokit_ids = [r["docket_no"] for r in convokit]

# %%
superscotus = []
with open("data/super_scotus/case_with_all_sources_with_companion_cases_tag.jsonl", "r") as f:
    reader = jsonlines.Reader(f)
    for row in reader:
        row.pop("utterances", None)
        row.pop("justia_sections", None)
        superscotus.append(row)

# %%
superscotus[0]
# Out:
# {'id': '1955_71',
#  'year': 1955,
#  'citation': '350 US 79',
#  'title': 'Affronti v. United States',
#  'petitioner': 'Affronti',
#  'respondent': 'United States',
#  'docket_no': '71',
#  'court': 'Warren Court',
#  'decided_date': 'Dec 5, 1955',
#  'url': 'https://www.oyez.org/cases/1955/71',
#  'transcripts': [{'name': 'Oral Argument - November 15, 1955',
#    'url': 'https://apps.oyez.org/player/#/warren3/oral_argument_audio/13127',
#    'id': 13127,
#    'case_id': '1955_71'}],
#  'adv_sides_inferred': True,
#  'known_respondent_adv': True,
#  'advocates': {'Harry F. Murphy': {'id': 'harry_f_murphy',
#    'name': 'Harry F. Murphy',
#    'side': 1},
#   'John V. Lindsay': {'id': 'john_v_lindsay',
#    'name': 'John V. Lindsay',
#    'side': 0}},
#  'win_side': 0.0,
#  'win_side_detail': 2.0,
#  'scdb_docket_id': '1955-009-01',
#  'votes': {'j__john_m_harlan2': 2.0,
#   'j__hugo_l_black': 2.0,
#   'j__william_o_douglas': 2.0,
#   'j__earl_warren': 2.0,
#   'j__tom_c_clark': 2.0,
#   'j__felix_frankfurter': 2.0,
#   'j__harold_burton': 2.0,
#   'j__stanley_reed': 2.0,
#   'j__sherman_minton': 2.0},
#  'votes_detail': {'j__john_m_harlan2': 1.0,
#   'j__hugo_l_black': 1.0,
#   'j__william_o_douglas': 1.0,
#   'j__earl_warren': 1.0,
#   'j__tom_c_clark': 1.0,
#   'j__felix_frankfurter': 1.0,
#   'j__harold_burton': 1.0,
#   'j__stanley_reed': 1.0,
#   'j__sherman_minton': 1.0},
#  'is_eq_divided': False,
#  'votes_side': {'j__john_m_harlan2': 0.0,
#   'j__hugo_l_black': 0.0,
#   'j__william_o_douglas': 0.0,
#   'j__earl_warren': 0.0,
#   'j__tom_c_clark': 0.0,
#   'j__felix_frankfurter': 0.0,
#   'j__harold_burton': 0.0,
#   'j__stanley_reed': 0.0,
#   'j__sherman_minton': 0.0},
#  'scdb_elements': {'caseId': '1955-009',
#   'docketId': '1955-009-01',
#   'caseIssuesId': '1955-009-01-01',
#   'voteId': '1955-009-01-01-01',
#   'dateDecision': '12/5/1955',
#   'decisionType': 1,
#   'usCite': '350 U.S. 79',
#   'sctCite': '76 S. Ct. 171',
#   'ledCite': '100 L. Ed. 2d 62',
#   'lexisCite': '1955 U.S. LEXIS 35',
#   'term': 1955,
#   'naturalCourt': 1403,
#   'chief': 'Warren',
#   'docket': '71',
#   'caseName': 'AFFRONTI v. UNITED STATES',
#   'dateArgument': '11/15/1955',
#   'dateRearg': nan,
#   'petitioner': 126.0,
#   'petitionerState': nan,
#   'respondent': 27.0,
#   'respondentState': nan,
#   'jurisdiction': 1.0,
#   'adminAction': nan,
#   'adminActionState': nan,
#   'threeJudgeFdc': 0.0,
#   'caseOrigin': 87.0,
#   'caseOriginState': nan,
#   'caseSource': 28.0,
#   'caseSourceState': nan,
#   'lcDisagreement': 0.0,
#   'certReason': 2.0,
#   'lcDisposition': 2.0,
#   'lcDispositionDirection': 1.0,
#   'declarationUncon': 1.0,
#   'caseDisposition': 2.0,
#   'caseDispositionUnusual': 0.0,
#   'partyWinning': 0.0,
#   'precedentAlteration': 0.0,
#   'voteUnclear': 0.0,
#   'issue': 90320.0,
#   'issueArea': 9.0,
#   'decisionDirection': 1.0,
#   'decisionDirectionDissent': 0.0,
#   'authorityDecision1': 4.0,
#   'authorityDecision2': nan,
#   'lawType': 6.0,
#   'lawSupp': 600.0,
#   'lawMinor': '18 U.S.C. § 3651',
#   'majOpinWriter': 79.0,
#   'majOpinAssigner': 90.0,
#   'splitVote': 1,
#   'majVotes': 9,
#   'minVotes': 0},
#  'convos': {'ids': ['13127'],
#   'speaker': {'harry_f_murphy': {'name': None, 'type': 'A', 'side': 1},
#    'john_v_lindsay': {'name': None, 'type': 'A', 'side': 0},
#    'j__earl_warren': {'name': 'Earl Warren', 'type': 'J', 'side': None},
#    'j__william_o_douglas': {'name': 'William O. Douglas',
#     'type': 'J',
#     'side': None},
#    '<INAUDIBLE>': {'name': '<INAUDIBLE>', 'type': 'U', 'side': None},
#    'j__felix_frankfurter': {'name': 'Felix Frankfurter',
#     'type': 'J',
#     'side': None},
#    'j__stanley_reed': {'name': 'Stanley Reed', 'type': 'J', 'side': None}},
#   'utterances': [[{'speaker_id': 'j__earl_warren',
#      'text': 'Number 71, Lonnie Affronti versus United States of America.\nMr. Murphy.',
#      'start_times': [0.0, 7.624],
#      'stop_times': [7.624, 9.218]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'May it please the Court.\nWe are here by writ of certiorari to the Eighth Circuit.\nThere is one question to be decided in this case, decided carefully.\nUpon sentence to consecutive sentences or terms by a District Court.\nThe defending pattern started the service of a first sentence.\nThus, the District Court thereafter have jurisdiction to suspend the execution of the remaining sentences and place the defendant on probation.',
#      'start_times': [9.218, 11.538, 15.653, 22.722, 28.849, 33.575],
#      'stop_times': [11.538, 15.653, 22.722, 28.849, 33.575, 48.138]},
#     {'speaker_id': 'j__william_o_douglas',
#      'text': 'Consecutive sentences.',
#      'start_times': [48.138],
#      'stop_times': [49.315]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "Consecutive sentences.\nIn this case, the defendant, Affronti, was indicted in 1932 by a grand jury in the Western District of Missouri.\nCharged in an indictment in ten counts with the illegal sale of narcotics.\nI've mentioned the dates because they, if not of importance, will be of interest.\nIn 1944, the defendant was brought in to the District Court at Kansas City on a writ of habeas corpus ad prosequendum from the Missouri State Penitentiary where he was in the service of a sentence for second degree murder.\nThe District Judge on that -- at that time was Judge Caskie Collet.\nUpon trial before a jury, the defendant was acquitted on the first of the ten counts, found guilty on the remaining nine and sentence was pronounced disclosed.\nOn all nine counts of the -- the indictment, he was sentenced to serve five years which was the maximum sentence under the statute that had been violated.Sentences two, three, four and five were pronounced to run consecutively.\nThe remaining five sentences, sentence was suspended and the defendant was to be placed upon probation for a period of 25 years.\nThe judgment further provided that the sentence on the second count would be to commence at the time he was released from authorities in Missouri State.\nIn 1949, after his release from the Missouri State Penitentiary, he was delivered to the United States Marshal for the service of the first five years of the second count of the indictment.\nIn 1953, four years later --",
#      'start_times': [49.315,
#       51.844,
#       60.81,
#       67.083,
#       72.584,
#       89.839,
#       95.873,
#       109.956,
#       128.326,
#       140.142,
#       154.125,
#       170.163],
#      'stop_times': [51.844,
#       60.81,
#       67.083,
#       72.584,
#       89.839,
#       95.873,
#       109.956,
#       128.326,
#       140.142,
#       154.125,
#       170.163,
#       174.058]},
#     {'speaker_id': '<INAUDIBLE>',
#      'text': 'Was the aggregate prison sentence was 20 or 25 years?',
#      'start_times': [174.058],
#      'stop_times': [176.766]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'Twenty years.',
#      'start_times': [176.766],
#      'stop_times': [177.525]},
#     {'speaker_id': '<INAUDIBLE>',
#      'text': 'Twenty years.',
#      'start_times': [177.525],
#      'stop_times': [177.844]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "Twenty years, four -- four counts of five years.\nBut the computation is a question whether he had yet started the service as -- as second of his third five years, but in 1943, at which time Judge Duncan had succeeded Judge Collet as the District Judge in that division, Judge Collet having been promoted to the Eighth Circuit bench.\nA motion was filed on his behalf requesting that the remaining sentences yet to be served, either the third, fourth, and fifth counts or the fourth and fifth, that the execution of the sentence as yet to be served be suspended and be placed on probation.\nNow, in -- two months prior to the filing of the motion on behalf of the petitioner in the District Court, Judge Reeves, another division of the Western District had ruled in the case of Phillips versus the United States for the facts as far as sentences are concerned, were identical with the facts in this case, and that Phillips, the defendant, was in the service of the first of three consecutive terms.\nThat the Court was without jurisdiction to entertain such a motion as the term had passed and the 60 days had -- had passed when he had -- after he had been first sentenced.\nPending the appeal of the Phillips case, Judge Duncan held in abeyance of ruling on the Affronti case.\nOn appeal to the United States Court of Appeals for the Eighth Circuit, the Phillips decision was affirmed.\nOn that bench, sitting as a member of the Court of Appeals, was Judge Collet.\nAnd in a dissenting opinion, he held that a District Court in his opinion had a right to retain jurisdiction over sentences yet to be served.\nAfter the Phillips case was passed, the time had passed, no application was made to this Court for certiorari, although the Court of Appeals had recommended that he'd be permitted to apply without the payment of cost.\nThe Court -- appeal was taken in the Affronti case to the same court.\nAnd again, on that same court, Judge Collet sat as a member of the Court of Appeals.\nFollowing the Phillips case, the Court of Appeals affirmed the Phillips case.\nJudge Collet consistently again dissenting.\nAgain, that Court recommended that Affronti be permitted to apply for certiorari without the payment of costs.\nThe basis of the ruling in the Phillips case, opinion by Judge Reeves, the District Judge and followed up by the Court of Appeals, was an early case passed on this Court in 1948 by the opinion written by Chief Justice Taft, Murray versus the United States, in which the facts briefly were these.\nA man by the name of Cook had been sentenced in a Texas District Court for a total of 14 years and some months.\nA man in Nebraska had been sentenced to three months on six counts to run concurrently.\nAfter the defendant Murray had served one day of his three-month sentence, the sentencing judge made an order suspending the execution of that sentence and placed Murray on probation for the balance of his term.\nShortly thereafter in Texas, the District Court in the Cook case, after the service of sentence had been began by Cook for several years at least, on the one sentence according to the opinion, the Court in that case ordered the defendant placed on probation, suspended the execution of the remaining sentence then being served.\nUpon appeal by the Government to this Court, certiorari from the Eighth Circuit and the Fifth, I believe it was, the opinion held that having once -- once started the service of the sentence, the District Court was without power to place the defendant on probation suspend the execution of that sentence.\nIn that case, there was no question of consecutive sentences, although perhaps, in the Cook case, the sentence actually was of sentences running consecutively.\nBut that doesn't appear to have been of any moment at least to the Court in the Murray opinion.\nThat created, if not confusion, at least some difference of opinions in the different circuits as to the right of the sentencing judge under the Probation Act  ...
#      'start_times': [177.844,
#       183.613,
#       204.06,
#       225.112,
#       253.196,
#       268.426,
#       279.334,
#       288.505,
#       293.813,
#       307.465,
#       323.261,
#       328.14,
#       334.148,
#       340.852,
#       344.534,
#       355.43,
#       381.8,
#       390.906,
#       400.429,
#       417.383,
#       442.457,
#       469.103,
#       479.852,
#       488.248,
#       504.031,
#       517.432,
#       531.051,
#       541.168],
#      'stop_times': [183.613,
#       204.06,
#       225.112,
#       253.196,
#       268.426,
#       279.334,
#       288.505,
#       293.813,
#       307.465,
#       323.261,
#       328.14,
#       334.148,
#       340.852,
#       344.534,
#       355.43,
#       381.8,
#       390.906,
#       400.429,
#       417.383,
#       442.457,
#       469.103,
#       479.852,
#       488.248,
#       504.031,
#       517.432,
#       531.051,
#       541.168,
#       559.587]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'Mr. Murphy, what statutory language do you rely upon for your position?',
#      'start_times': [559.587],
#      'stop_times': [566.261]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'Well the -- the probation statute, I think, which the section --',
#      'start_times': [566.261],
#      'stop_times': [576.08]},
#     {'speaker_id': 'j__earl_warren',
#      'text': '3651?',
#      'start_times': [576.08],
#      'stop_times': [576.865]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': '3651 --',
#      'start_times': [576.865],
#      'stop_times': [578.376]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'What language there do you rely on to support your position?',
#      'start_times': [578.376],
#      'stop_times': [582.541]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "Well, frankly, I'm relying upon the language in the Kirk case which held -- holds that the Court has jurisdiction to suspend the execution of sentences yet not served.",
#      'start_times': [582.541],
#      'stop_times': [594.213]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'You mean beyond any statute?',
#      'start_times': [594.213],
#      'stop_times': [597.487]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'That --',
#      'start_times': [597.487],
#      'stop_times': [597.517]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'Or do -- do they get that power through a statute?',
#      'start_times': [597.517],
#      'stop_times': [600.966]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "Well, that's a little bit puzzling to me at this time.\nThe statute hasn't been --",
#      'start_times': [600.966, 604.592],
#      'stop_times': [604.592, 605.03]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'And to me too.',
#      'start_times': [605.03],
#      'stop_times': [606.127]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'It hasn\'t been construed, the language of the former statute was changed formerly reading after a conviction and to comply with the criminal -- as -- as part of the criminal code in the criminal statutes, the language was changed to "upon service or the entering of a judgment conviction."\nSo, the conflict before this Court is between the Ninth Circuit in the Kirk case, was held on appeal that the District Court did have power, had been discretionary, of course, to suspend the execution of sentence yes -- yet not served.\nAnd the Eighth Circuit in this case which held before, had no jurisdiction.',
#      'start_times': [606.127, 628.785, 646.71],
#      'stop_times': [628.785, 646.71, 651.628]},
#     {'speaker_id': 'j__earl_warren',
#      'text': "But you don't rely on any statutory language saying that the Court has the authority to grant probation under these circumstances.",
#      'start_times': [651.628],
#      'stop_times': [659.558]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'No, sir.',
#      'start_times': [659.558],
#      'stop_times': [661.451]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'This -- is it not necessary for you to do so in view of the decision way back to the case of my youth, in Ex Parte United States in which this Court denies to the District Court the inherent power for -- placing people on probation.',
#      'start_times': [661.451],
#      'stop_times': [676.601]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "That's the Ex --",
#      'start_times': [676.601],
#      'stop_times': [676.75]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'That practice had been enforced time out of lines and there are no facilities that prior to prosecuting judges that this Court said, original place of jurisdiction.\nIs that not the Probation Act this time, if you know?\nMust even to turn on the statutes?',
#      'start_times': [676.75, 686.029, 689.621],
#      'stop_times': [686.029, 689.621, 691.232]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "Well, the statute, which was involved in the -- in the Murray case had been enacted as I recall in 1925.\nThis was a basis for the ruling there that the Court could grant probation, which followed some eight years after, I think it's Ex Parte Lange case that you have reference to and down to 1918.\nIn any event, the statute was passed in 1925, which permitted District Courts to suspend the execution and place defendants on probation.\nThe -- the trouble here is that the question of the definition of a final judgment or a single judgment are separate sentences merged into one separate judgment so that the District Court would not have jurisdiction.",
#      'start_times': [691.232, 698.801, 714.031, 726.655],
#      'stop_times': [698.801, 714.031, 726.655, 741.974]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "You still haven't furnished with the problem of construction by -- if your answer to Chief Justice today relate what I -- my means heard and I don't think he's got any permission at all --",
#      'start_times': [741.974],
#      'stop_times': [755.045]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'Well, the --',
#      'start_times': [755.045],
#      'stop_times': [755.635]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "-- to so select the statute even though the statute doesn't leave the word which fits your case.",
#      'start_times': [755.635],
#      'stop_times': [761.282]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'Well, of course, we have here in this particular case of conflict where Courts of Appeals have decided differently and --',
#      'start_times': [761.282],
#      'stop_times': [767.858]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "But it's what they reflects to draw on the construction of the Probation Act, didn't they?",
#      'start_times': [767.858],
#      'stop_times': [772.902]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "That's correct.",
#      'start_times': [772.902],
#      'stop_times': [773.87]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'Well, I think you must have misunderstood the difficulty of the question.',
#      'start_times': [773.87],
#      'stop_times': [781.412]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "Well, I -- I understand that you're asking what statutory provisions we have here which give the District Court the right to suspend the execution.",
#      'start_times': [781.412],
#      'stop_times': [790.548]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'And you stay forward.',
#      'start_times': [790.548],
#      'stop_times': [791.671]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "And I state there's no definition to this particular statute which says the Court does or does not have that right.",
#      'start_times': [791.671],
#      'stop_times': [796.88]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "That's a different story to say.\nYou mean as if it's spelled out in the statute.",
#      'start_times': [796.88, 798.391],
#      'stop_times': [798.391, 800.89]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "I'd say there is some confusion, exists in the wording of the statute without a definition from this Court.",
#      'start_times': [800.89],
#      'stop_times': [806.043]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'Whatever rights you press, they have -- must have come out of that statute --',
#      'start_times': [806.043],
#      'stop_times': [810.354]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'That is correct.',
#      'start_times': [810.354],
#      'stop_times': [810.613]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': '-- on your account of it.',
#      'start_times': [810.613],
#      'stop_times': [812.108]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'Absent the statute, the Court has been held to have no power to place -- suspend a non-probation.',
#      'start_times': [812.108],
#      'stop_times': [818.755]},
#     {'speaker_id': 'j__stanley_reed',
#      'text': 'The statute says, upon entering a judgment of to which --',
#      'start_times': [818.755],
#      'stop_times': [825.969]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'That is right.',
#      'start_times': [825.969],
#      'stop_times': [826.51]},
#     {'speaker_id': 'j__stanley_reed',
#      'text': '-- they suspended it.',
#      'start_times': [826.51],
#      'stop_times': [828.462]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "When does the judgment comes effective, that's the thing that we haven't forced here.",
#      'start_times': [828.462],
#      'stop_times': [833.035]},
#     {'speaker_id': 'j__stanley_reed',
#      'text': 'Not to say were discussed there --',
#      'start_times': [833.035],
#      'stop_times': [834.142]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'Upon, immediately?',
#      'start_times': [834.142],
#      'stop_times': [835.055]},
#     {'speaker_id': 'j__stanley_reed',
#      'text': 'Upon -- upon entering.',
#      'start_times': [835.055],
#      'stop_times': [837.133]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "That's right.\nWell, that's the -- that's the disturbing thing about the whole thing here, is that we have a man who is serving four sentences, totaling 20 years.\nJudge Collet in his dissenting opinion in both appeals, that we're bringing in this case what he had said in the opinion in the Phillips case.\nHeld that the sentencing judge in his opinion had the power at any time for the commencement of the service of any of the remaining sentences to come in and set that aside by putting the --",
#      'start_times': [837.133, 838.141, 849.074, 857.64],
#      'stop_times': [838.141, 849.074, 857.64, 871.73]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "Judge -- Judge Collet didn't rely on some inherent power.He said he mustn't be barred from having that view by the Probation Act.",
#      'start_times': [871.73],
#      'stop_times': [881.214]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': "That is right.\nWell, we have, for consideration, just the -- as I -- as I view it, the three cases, the early case of Murray against the United States, the Phillips case in this Circuit and the Kirk case in the Ninth Circuit, whereas in the Court's definition of the statute, if the Court may retain jurisdiction at any time for any of the remaining sentences served in, the Court would have jurisdiction to suspend the execution of the sentence of those remaining -- the balance of those sentences.\nWell, that's it.",
#      'start_times': [881.214, 884.335, 916.288],
#      'stop_times': [884.335, 916.288, 922.912]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'Mr. Lindsay.',
#      'start_times': [922.912],
#      'stop_times': [924.567]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'May it please the Court.\nWhen this Court decided the (Inaudible) case in 1916, which I believe is the case that Mr. Justice Frankfurter was referring to in Volume 242, it made two points clear.\nFirst of all, that there was no power that common law -- to suspend a sentence absolutely or permanently.\nIt did not exist.\nAnd secondly, that the federal courts had no such power, despite the fact at which existed in some federal and in some state courts at the time.\n"Recourse must be had to the Congress," said this Court, whose power in this field in the language of the Court is adequately complete.\nThe result of the (Inaudible) case was continued and reinforced agitation on the part of the exponents of probation were some sort of legislation in this field, and it resulted in 1925 in the passage of the Probation Act of that year.\nAnd that Act provided that after conviction or plea of guilty or nolo contendere, the Court, District Court, may suspend sentence and grant probation that the Court may suspend at the imposition or the execution of sentence and grant probation.\nAnd of course that statute, spoken terms of a general or single sentence, there was no differentiation made in the case of a sentence involving multiple counts or indictments.\nThe chief difficulty that the federal courts had with the application of that statute was the question which was answered by this Court in Murray in volume 275, 1928.\nThere are other subsidiary difficulties which the federal courts had but they\'re not of immediate concern to this problem today.\nAnd if Murray case held -- this Court there held that the District Court loses power to suspend sentence once the defendant has entered upon the service of his sentence.\nAnd in the language of this Court, it was stated that when any part of the sentence has been served, the District Court loses power to entertain a motion to put it to suspend sentence and grant probation.',
#      'start_times': [924.567,
#       927.354,
#       938.942,
#       946.437,
#       947.978,
#       958.478,
#       967.521,
#       984.026,
#       1003.912,
#       1016.898,
#       1029.279,
#       1036.798,
#       1047.753],
#      'stop_times': [927.354,
#       938.942,
#       946.437,
#       947.978,
#       958.478,
#       967.521,
#       984.026,
#       1003.912,
#       1016.898,
#       1029.279,
#       1036.798,
#       1047.753,
#       1061.191]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'Is that a case like this?',
#      'start_times': [1061.191],
#      'stop_times': [1064.243]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'It was not, Mr. Justice.\nThe Murray case had came up -- it was two cases as counsel has pointed out.\nOne concerned a -- a sentence for 14 years and 9 months and the application for probation was presented to the District Court four years later.\nIt actually was a case involving consecutive terms, but it was not argued, presented, or decided by this Court on that basis.\nThe Cook case incidentally, which was the companion case decided by the Court at the same time, involved a sentence for three months.\nAnd one day after the incarceration, the prisoner came to the Court and asked to have his sentence suspended and probation granted and the Court, as counsel has pointed out, granted the motion.\nBut the basis for the holding of the Court in the Murray case, which again was concerned with the 1925 statute prior to the 1948 revision of the Criminal Code is important.\nThree points stand out.\n"One," said to this Court, “The reason for the Probation Act was this, was to grant to young and new first violators of the law a chance to reform and to avoid the contaminating influence of association with hardened criminals at the time of the sentence."\nAvoidance at the time of the sentence was the key that was expounded to the Congress by the proponents of the legislation at the time it was passed.\nAnd indeed, that was the background against which the legislation was passed.\n"Secondly," said this Court, “Congress could not have intended in passing this legislation to require the District Court, days, months, indeed years later to entertain applications for suspension of sentence and probation after the prisoner has been turned over to the Attorney General for custody and has commenced his -- his service.”\nThirdly, Congress and this is related to point number 2.\n"Thirdly," said the Court in the Murray Case, “Congress could not have intended an overlap with the resulting conflicts that would occur between the operation of the probation of the parole statute which even then provided for parole after one-third of the aggregate sentence and the application of the good time statutes -- the credit for good conduct, which is given to prisoners.\nOn the one hand, and indeed of course, the power of clemency which is always available, the presidential power of clemency, those on the one hand and the judiciary on the other hand.\nNow, the Government submits that the reason and logic set forth by this Court in the Murray case is equally -- applies with equal force and vigor under the 1948 revision to the Probation Act of the code of -- and indeed to the instant case.\nWell, the 1948 revision did only two things to the 1925 Act.\nFirst, it changed the initial language that after conviction or plea of guilty or nolo contendere, the District Court may suspend sentence and grant a probation, it changed that to read upon entering judgment of conviction.\nNow, the Reviser\'s Notes do not indicate that there was any substantive change intended.\nThe Reviser\'s Notes only indicate this, that the change in language was made because the excess language was dropped as unnecessary, said the revisers.\nNow, it is submitted that in the absence of substantive change, that the Reviser\'s and the Congress must have known the construction that have been placed upon the Probation Act by this Court in the Murray case.\nAnd indeed, if anything, the use of the word upon indicates a more stringent application of the use of probation than had been prior to -- than have been the case before this.',
#      'start_times': [1064.243,
#       1066.056,
#       1070.444,
#       1081.576,
#       1090.021,
#       1097.083,
#       1110.061,
#       1124.734,
#       1126.802,
#       1145.305,
#       1155.143,
#       1159.7,
#       1180.876,
#       1184.541,
#       1208.846,
#       1221.07,
#       1240.601,
#       1247.036,
#       1262.017,
#       1268.999,
#       1277.992,
#       1289.539],
#      'stop_times': [1066.056,
#       1070.444,
#       1081.576,
#       1090.021,
#       1097.083,
#       1110.061,
#       1124.734,
#       1126.802,
#       1145.305,
#       1155.143,
#       1159.7,
#       1180.876,
#       1184.541,
#       1208.846,
#       1221.07,
#       1240.601,
#       1247.036,
#       1262.017,
#       1268.999,
#       1277.992,
#       1289.539,
#       1298.976]},
#     {'speaker_id': '<INAUDIBLE>',
#      'text': 'Well, you think even under this statute, the Murray case is still good law, the judge can do it anytime up to the commencement of service of sentence?',
#      'start_times': [1298.976],
#      'stop_times': [1306.932]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "I do, Mr. Justice.\nNow, the second change that was made in the -- by the Revisers were these.\nThat an additional sentence was inserted which ran as follows.\nThat probation may be limited to one or -- or more counts or indictments but that in the absence of a specific limitation, it shall extend to the entire sentence, singular, and judgment.\nNow, the Reviser's Notes indicate, in that respect only this.\nThat that change or addition reflected the existing practice in the federal courts which was true.\nThis Court, in two decisions in volumes 302 and 303 had approved the practice of -- at the time of judgment, at the time of sentencing, of sentencing, of sending a man to jail on some counts and granting probation -- suspending sentence and granting probation on other counts and the same with respect to multiple indictments tried together.\nSo those two questions were settled.\nAnd what the Reviser's Notes indicated was correct that existing practice was being confirmed.\nNow, Judge Sanborn in the Phillips case -- the Phillips case and the Affronti case and instant case come up from the Eighth Circuit in which the Government argues is the correct rule of law.\nAnd I should add too that the Eighth Circuit is supported by the very articulate opinion of Judge Dobie in the Fourth Circuit.\nJudges Parker and Soper going along with him which in turn is based in large part on the excellent opinion of Judge Chestnut in the court below.\nThose two Circuits argue this way in substance.\nThat the Probation Act is not an isolated act.\nThat at the time of the revision of the code, the Revisers intended a comprehensive and orderly revision of all of the statutes relating to crime and criminal procedure.\nAnd then it could not have been the intent of the Congress at that time to upset the construction that have been placed on the 1925 Act by this code which clearly enunciated the desirability of having a division between the Judicial Branch of the Government and the Executive Branch of the Government when it comes to the business of modification or reorganizing a sentence of a man who is in the custody of the Attorney General.",
#      'start_times': [1306.932,
#       1309.182,
#       1314.6,
#       1318.6,
#       1337.938,
#       1341.868,
#       1349.201,
#       1373.724,
#       1376.094,
#       1384.04,
#       1398.206,
#       1407.915,
#       1417.175,
#       1423.467,
#       1427.928,
#       1438.828],
#      'stop_times': [1309.182,
#       1314.6,
#       1318.6,
#       1337.938,
#       1341.868,
#       1349.201,
#       1373.724,
#       1376.094,
#       1384.04,
#       1398.206,
#       1407.915,
#       1417.175,
#       1423.467,
#       1427.928,
#       1438.828,
#       1462.648]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "I don't -- I don't quite see how that argument had to this kind of a situation.\nCertainly, I don't see what the argument in this expression, executive confines of conflict that cuts the clause saying that they should give separate sentences and the sentence number two is to run -- is to begin to run after sentence number one has expired.\nYou haven't entered upon that sentence.\nIn other words, I should like to tell you before you sit down, why do you think that this is a question of reading?\nThis statute in the matter of reading English or whether they have entered upon the constructions, one's attitude towards the probation statute.",
#      'start_times': [1462.648, 1469.58, 1485.573, 1488.032, 1495.127],
#      'stop_times': [1469.58, 1485.573, 1488.032, 1495.127, 1505.724]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'I think --',
#      'start_times': [1505.724],
#      'stop_times': [1505.774]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'I can -- I can understand --',
#      'start_times': [1505.774],
#      'stop_times': [1506.559]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': '-- I think both.',
#      'start_times': [1506.559],
#      'stop_times': [1507.186]},
#     {'speaker_id': 'j__earl_warren',
#      'text': '-- one view or the other.',
#      'start_times': [1507.186],
#      'stop_times': [1508.164]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'I think both, Mr. Justice.\nFirst of all, if you read the statute, the statute says that the executed -- the imposition or the execution may be suspended with respect to one or more counts or indictments.\nBut then in the absence of any expressed limitation, shall extend to the entire sentence in the singular.\nThe statute nowhere talks in terms of sentences.\nIt talks in terms of counts or indictments.',
#      'start_times': [1508.164, 1509.625, 1521.865, 1528.082, 1531.317],
#      'stop_times': [1509.625, 1521.865, 1528.082, 1531.317, 1534.005]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "That's why I think -- looking for the intention of Congress and looking for the black cat, and is all through when the black cat isn't there.",
#      'start_times': [1534.005],
#      'stop_times': [1541.077]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'Possibly --',
#      'start_times': [1541.077],
#      'stop_times': [1541.19]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "It's more on the question --",
#      'start_times': [1541.19],
#      'stop_times': [1541.886]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'Possibly so.',
#      'start_times': [1541.886],
#      'stop_times': [1542.433]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': '(Voice Overlap) intention of Congress.',
#      'start_times': [1542.433],
#      'stop_times': [1542.874]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "Possibly so.\nI think in the absence of legislative history, it's -- it's probably --",
#      'start_times': [1542.874, 1544.097],
#      'stop_times': [1544.097, 1546.994]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'All right.',
#      'start_times': [1546.994],
#      'stop_times': [1547.217]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': '-- permissible to turn to the statute.',
#      'start_times': [1547.217],
#      'stop_times': [1547.36]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'Now, how did that (Voice Overlap) that contemplate in this kind of a situation?',
#      'start_times': [1547.36],
#      'stop_times': [1552.261]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "I believe that they did contemplate this kind of a situation and I'll give you further reasons for that.",
#      'start_times': [1552.261],
#      'stop_times': [1556.48]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'Is it in the legislative history?',
#      'start_times': [1556.48],
#      'stop_times': [1558.273]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'Not in legislative history.',
#      'start_times': [1558.273],
#      'stop_times': [1559.049]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'All right.',
#      'start_times': [1559.049],
#      'stop_times': [1559.53]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "I'll say that --",
#      'start_times': [1559.53],
#      'stop_times': [1559.898]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "Then we haven't got anything from Congress except -- except this Act was -- the duty weave this Act in conformity or in harmony with other acts.",
#      'start_times': [1559.898],
#      'stop_times': [1568.364]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'And you have this too, Mr. Justice, which is to say, that -- that if substantive change had been intended --',
#      'start_times': [1568.364],
#      'stop_times': [1573.663]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "I don't (Voice Overlap) --",
#      'start_times': [1573.663],
#      'stop_times': [1574.015]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "The Reviser's Notes would have -- would -- would have stated as much.",
#      'start_times': [1574.015],
#      'stop_times': [1576.932]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "I thought but I don't think 1948 made any changed.\nI'm talking about the construction referring to that.",
#      'start_times': [1576.932, 1579.52],
#      'stop_times': [1579.52, 1582.015]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "Apart from the legislative history that I've given you as to the desirability of probation at the time of the sentence, we don't get any help.\nNow there, that's the key, really.",
#      'start_times': [1582.015, 1590.31],
#      'stop_times': [1590.31, 1592.408]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'And will be entirely deciding the 1948, of this Act, I get nothing.',
#      'start_times': [1592.408],
#      'stop_times': [1596.1]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'Mr. Lindsay, many of the States of the union have had a longer experience with probation than the Federal Government itself.\nI wonder, as far as you know if there is anything in the statutes or the general practice in the various States on probation that would indicate the probation system is in spirit different from anything you would have indicated here?',
#      'start_times': [1596.1, 1605.738],
#      'stop_times': [1605.738, 1629.326]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "Well, the -- the practice of all of the Sates with the exception of one, State of Tennessee, have probation statutes.\nEven Tennessee has one with respect to juveniles.\nThere is a great difference in their application and I can't -- I can't answer your question absolutely directly.\nI can't tell you that in New York, the statute is much the same as the federal statute.\nAnd although I don't believe there are any cases directly on this point here from a reading of the statute, which terms -- which speaks in terms of commencement of imprisonment, which is the cutoff date, the same result would follow unless he would doubt the theory that is advanced by the petitioner here that you've got entirely separate and distinct sentences when you have a multiple count sentence.",
#      'start_times': [1629.326, 1637.302, 1641.001, 1647.562, 1654.405],
#      'stop_times': [1637.302, 1641.001, 1647.562, 1654.405, 1674.383]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'Yes.\nWell, what I -- what I was getting at, do you know of any -- any States, I do not, where a judge can sentence a man to prison then at the end of five years or so, give him probation?',
#      'start_times': [1674.383, 1675.02],
#      'stop_times': [1675.02, 1691.164]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'I do not.',
#      'start_times': [1691.164],
#      'stop_times': [1691.764]},
#     {'speaker_id': 'j__earl_warren',
#      'text': "There may be -- I don't --",
#      'start_times': [1691.764],
#      'stop_times': [1692.411]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'I do not.',
#      'start_times': [1692.411],
#      'stop_times': [1693.011]},
#     {'speaker_id': 'j__earl_warren',
#      'text': "I don't know.",
#      'start_times': [1693.011],
#      'stop_times': [1693.2]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'I do not.\nI do know that in --',
#      'start_times': [1693.2, 1693.658],
#      'stop_times': [1693.658, 1694.815]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'Not on this case.',
#      'start_times': [1694.815],
#      'stop_times': [1696.197]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'I thought it was.',
#      'start_times': [1696.197],
#      'stop_times': [1696.947]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "Not on this case.\nYou can't give probation for the sentence unless the Government began giving probation for the sentence to preserve it.",
#      'start_times': [1696.947, 1698.412],
#      'stop_times': [1698.412, 1708.898]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "That -- that is the -- the entire theory of the petitioner's argument.",
#      'start_times': [1708.898],
#      'stop_times': [1712.341]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': '(Voice Overlap) --',
#      'start_times': [1712.341],
#      'stop_times': [1712.59]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "I'll concede that.",
#      'start_times': [1712.59],
#      'stop_times': [1713.379]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "All I'm saying is that is different from anything we've go for that.\nI'm not stating you're not right.",
#      'start_times': [1713.379, 1717.922],
#      'stop_times': [1717.922, 1719.373]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'That this Court has had.\nThat is correct.',
#      'start_times': [1719.373, 1720.338],
#      'stop_times': [1720.338, 1720.511]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "That's a part of it.",
#      'start_times': [1720.511],
#      'stop_times': [1721.27]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'That is correct.',
#      'start_times': [1721.27],
#      'stop_times': [1721.837]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "And I'm suggesting --",
#      'start_times': [1721.837],
#      'stop_times': [1722.125]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "I'll concede that.",
#      'start_times': [1722.125],
#      'stop_times': [1722.626]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': '-- that the practice of probation in the Federal Government until that part of United States came along as longer than the States had, mostly.\nBecause of our statute, the federal courts up to the (Inaudible) case, have been exercising this function as a matter of inherent or prior to the Court --',
#      'start_times': [1722.626, 1731.265],
#      'stop_times': [1731.265, 1738.969]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'That is correct.',
#      'start_times': [1738.969],
#      'stop_times': [1739.818]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': '-- for decades.\nThe first in 56 years and this Court said, something that has been in practice in the courts for 56 years but beyond their power.',
#      'start_times': [1739.818, 1740.607],
#      'stop_times': [1740.607, 1746.671]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'That is correct.\nI -- I think that the State of Massachusetts too had been following a -- a rule of laying the case on the file as they call it, which has amounted to suspension.',
#      'start_times': [1746.671, 1747.271],
#      'stop_times': [1747.271, 1756.3]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'I think you would still find, Mr. Lindsay, though that many States have had -- it may deal more experience with probation on the Federal Government.',
#      'start_times': [1756.3],
#      'stop_times': [1764.096]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'I think that that may well be so.\nI have in the -- I -- I do know that in the State of California that there is no -- there is no power in the part of the judge to -- to later use, to reach back and make an adjustment in the sentence.',
#      'start_times': [1764.096, 1766.035],
#      'stop_times': [1766.035, 1775.664]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "I -- I rejected -- he surrendered under a relatively used, the number of criminal prosections in the federal courts as very (Inaudible) as compared to the long -- the whole range of criminal prosecutions in the States, that's also.",
#      'start_times': [1775.664],
#      'stop_times': [1789.319]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "I don't argue --",
#      'start_times': [1789.319],
#      'stop_times': [1789.498]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'Conclusive there is that for perhaps 50 years prior to the part of United States, probation was exercised by federal judges in severe crimes as a matter of inherent jurisdiction, deemed to be part of the function of courts.',
#      'start_times': [1789.498],
#      'stop_times': [1806.341]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'That is right.\nAnd the decision of this Court --',
#      'start_times': [1806.341, 1806.957],
#      'stop_times': [1806.957, 1807.713]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'But then along came -- then along came at the part of United States.',
#      'start_times': [1807.713],
#      'stop_times': [1811.037]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'Which was a great --',
#      'start_times': [1811.037],
#      'stop_times': [1811.445]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'I think --',
#      'start_times': [1811.445],
#      'stop_times': [1811.618]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': '-- shock to people when it came.',
#      'start_times': [1811.618],
#      'stop_times': [1813.153]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "I can assure you I can feel it under the shock.\nThen came the statutes that we're now construing.\nI throw out the 1948 amendment.\nI don't think that attaches.\nI do say that they have a new question here that is not to be answered by any of the prior decisions or by the language into it.",
#      'start_times': [1813.153, 1816.745, 1820.771, 1823.136, 1824.512],
#      'stop_times': [1816.745, 1820.771, 1823.136, 1824.512, 1832.339]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'Well now, let me give you some additional reasons as to why I think that not only that the Murray case controls on this new statute but as to why it should control.\nAnd I think that was the second half --',
#      'start_times': [1832.339, 1841.962],
#      'stop_times': [1841.962, 1843.414]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': '(Voice Overlap) --',
#      'start_times': [1843.414],
#      'stop_times': [1843.418]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': '-- the second half of the original question.',
#      'start_times': [1843.418],
#      'stop_times': [1845.012]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': '-- but I think a serious question.',
#      'start_times': [1845.012],
#      'stop_times': [1847.03]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "In this Phillips case, which is really the key leading decision, parole had already been denied the applicant at the time that the trial judge turned down his application for suspension and probation.\nIn the Mann case which was the lower court decision of Judge Chestnut, which was subsequently approved by Judge Dobie in the Court of Appeals for the Fourth Circuit.\nThere had been three prior applications to the District Court.\nAnd in both cases, the Court stress this.\nThat it is the Executive Branch of the Government exclusively that has supervision of the prisoner, that has the skills at its command to measure the extent of rehabilitation.\nAnd then every single one of the cases where an application has been brought to the District Court, the affidavits of the prisoner and the argument of counsel has always been this.\nThat the prisoner, while in prison, while in custody, has -- has shown such a remarkable degree of improvement and rehabilitation or is otherwise been of service to the Federal Government in other respects that he is now deserving and that the original sentence was too harsh or something else.\nAnd I -- I have -- submit that the chief difficulty with the -- the chief difficulty in the practical basis where the argument that is advanced by the petitioner that you can take a consecutive count sentence and divide it up into separate sentences, separate terms is this.\nIs that therefore, in later years, the exercise of the power of suspension and probation will depend entirely on the phraseology used by the trial judge in sentencing the man.\nIt's conceded by the petitioner in his brief -- in -- in his brief, I think, that the trial judge and indeed this is the argument that was used in the Eighth Circuit and Fourth Circuit as well.\nThat the trial judge can sentence any one of a number ways.\nHe can take the entire amount permissible.\nTake the series of counts and add them all together and then put it in the judgment in terms of the general sentence or something less than that.\nOr he can divide it up into terms, into counts and sentence into a separate terms and -- and order some to run concurrently and some to be consecutive or the whole bunch can be concurrent.",
#      'start_times': [1847.03,
#       1859.324,
#       1867.553,
#       1871.613,
#       1874.768,
#       1886.226,
#       1895.124,
#       1911.907,
#       1928.803,
#       1940.979,
#       1949.926,
#       1953.386,
#       1956.392,
#       1964.469],
#      'stop_times': [1859.324,
#       1867.553,
#       1871.613,
#       1874.768,
#       1886.226,
#       1895.124,
#       1911.907,
#       1928.803,
#       1940.979,
#       1949.926,
#       1953.386,
#       1956.392,
#       1964.469,
#       1974.917]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "But Mr. Lindsay, I have to have a prejudice arising -- arising there.\nIf I may say so, this argument of yours is full of flaw.\nWhat you're saying is that a judge has the discretion if a man is convicted on five counts or five indictments or probably.\nOr we can -- may give on each count, on each sentence or each indictment five years.\nHe may do that concurrently or he may do that consecutively or he may give a maximum or the intervening theory.\nWell, what kind of an argument is this that this would cut into that power if you have that power.\nThey could have exercised it before the sentence began and the question is whether the bars it, not whether he had with the power which we say here, of course, he had.\nWhere is that now?",
#      'start_times': [1974.917,
#       1979.907,
#       1983.394,
#       1994.0,
#       2001.32,
#       2010.716,
#       2016.049,
#       2025.917],
#      'stop_times': [1979.907,
#       1983.394,
#       1994.0,
#       2001.32,
#       2010.716,
#       2016.049,
#       2025.917,
#       2027.362]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'Why should -- why should the district judge at 20 years, 15 years later --',
#      'start_times': [2027.362],
#      'stop_times': [2030.732]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "It's a question -- all I'm saying is, it isn't the question, of phrasing.\nIt's a question of the exercise of discretion.\nIt's a question of phrasing.\nIt's a question of a determination by him whether the sentence and when he gets to require him, he could have five more years or whether he should have five years in serving.\nThat is the phrasing.",
#      'start_times': [2030.732, 2034.764, 2037.607, 2039.579, 2048.96],
#      'stop_times': [2034.764, 2037.607, 2039.579, 2048.96, 2050.733]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "I'll agree with you, Mr. Justice, but my argument is this.\nThat it doesn't make any sense to use the artificial device of saying that a sentence, which is no less final because it is -- it -- it has included in it multiple counts or indictments, is no less final.\nIt's artificial to say that you -- years later, can divide it up into separate counts and separate sentences, in Colet's separate sentences.",
#      'start_times': [2050.733, 2053.257, 2066.536],
#      'stop_times': [2053.257, 2066.536, 2076.0]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "Well I don't go on the -- I don't go on the compulsions of language and I have to change it.\nI'm saying that a judge may decide at the ultimate question.\nBut although a fellow has committed five hundred executions, he serviced only for one term, if it was.\nAll he may say --",
#      'start_times': [2076.0, 2082.371, 2087.206, 2095.355],
#      'stop_times': [2082.371, 2087.206, 2095.355, 2096.17]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': '25 years.',
#      'start_times': [2096.17],
#      'stop_times': [2096.489]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "(Voice Overlap) -- and then having thought some more about finality, he may say or he's dead wrong in having him for the 25 year-sentence.\nI was dead wrong.\nThis fellow, I think, begun to serve his second five years and I will now take think it has to be done as a matter of (Inaudible) to serve that sentence.\nI will now say, I will give him probation which I could have done ab initio.",
#      'start_times': [2096.489, 2107.663, 2109.178, 2118.955],
#      'stop_times': [2107.663, 2109.178, 2118.955, 2123.064]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': 'No.',
#      'start_times': [2123.064],
#      'stop_times': [2123.273]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "I'm not saying that argument is reducing.\nI'm suggesting to you that you merely ban the words around, we don't really get to the heart of this problem.",
#      'start_times': [2123.273, 2125.907],
#      'stop_times': [2125.907, 2131.303]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "Well, I think -- I -- I think that is correct.\nBut I think that my -- my argument is a perfectly permissible one on this score.\nAnd I -- I'm not sure -- I think you understand -- I'm not sure that you understand that if a general sentence for the multi -- for maximum amount is imposed, there is no power at a later date to make any adjustment.",
#      'start_times': [2131.303, 2133.152, 2137.354],
#      'stop_times': [2133.152, 2137.354, 2147.539]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "I agree with you but -- but that all goes back to the decision that's hooked in the Murray case, that once you begin the sentence, one day is too late.",
#      'start_times': [2147.539],
#      'stop_times': [2158.643]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "I hardly agreed and that's why I say that the real answer to this case here is that the underlying theory and reasons of this Court in the Murray case is the chief difficulty with the proposition that is put to this Court by the petitioner because the same reasons apply.\nNow, I -- I certainly will not argue at all that there are not weaknesses in the present system, and that it -- it would not be desirable that at future date in a particular sentence to have machinery that would give the Executive Branch of the Government the chance to take another look at it particularly where a parole of the man is not eligible for parole.\nBut I submit that if the -- if the proposition which is argued to this Court by the petitioner and this case is adopted, it would create a great deal of more mischief than has ever been -- that has been the result in particular cases where there had been hardship of -- in sentences or where a man truly has made remarkable adjustment and there should be an adjustment or reorganization of his sentence but the courts are not the bodies to do it.\nIt requires legislation if it's to be done and it's a power which should be exercised by the Executive Branch of the Government and not the judiciary.",
#      'start_times': [2158.643, 2175.575, 2197.776, 2223.72],
#      'stop_times': [2175.575, 2197.776, 2223.72, 2231.668]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "I don't think courts are good instrument for imposing sentence myself.",
#      'start_times': [2231.668],
#      'stop_times': [2235.684]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "I'm --",
#      'start_times': [2235.684],
#      'stop_times': [2236.181]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': "That doesn't -- that doesn't --",
#      'start_times': [2236.181],
#      'stop_times': [2237.096]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "Mr. Justice Frankfurter, I'm not going to quarrel with you on that point of -- of that there's a --",
#      'start_times': [2237.096],
#      'stop_times': [2241.657]},
#     {'speaker_id': 'j__felix_frankfurter',
#      'text': 'All right.',
#      'start_times': [2241.657],
#      'stop_times': [2242.546]},
#     {'speaker_id': 'john_v_lindsay',
#      'text': "And I think you would find a lot of support in the Executive Branch of Government for that -- for that argument.\nIndeed, I think that -- that among the leading experts of the probation system of course is the director of administrative office of the courts.\nAnd I think it's perfectly permissible that -- it's perfectly proper to argue because he has written about it in -- in two leading -- in two leading articles, one, in the 25th anniversary issue of federal probation published in 1950 and again, in volume 37, I think, of Virginia Law Review has argued very persuasively that probation is not the machinery to use -- to tamper with a sentence after a man has been turned over to the Attorney General.\nIndeed, he argues this way, that he divorce the practice which was approved in this Court in Fred versus Kelly & Kossman of allowing a split sentence, jailed on some counts, probation on other counts and which was adopted in 1948 by the Congress, although they intended no substitute change.\nHe deploys that practice because it said that it goes against the original purpose of probation which was to pluck the bland -- brand from the burning as this Court said in the Murray case, stop him from going to prison.\nAnd he argues further that the transition between jail and public life can only and best be done the machinery or parole and not by the exercise of the probation statute.\nI think that it's a -- it's perfectly proper to -- to argue this two that -- that one of the greatest needs in the prison administration is for certainty of sentence.\nThe director of the Bureau of Prisons will tell you that, although he is the first one to admit that there are hardships under the present cacophony of sentencing in -- in this Government.\nHe will argue that certainly, it's necessary from the point of view of the management of the prisons so that they can program the man, and certainty is important from the program of the prisoner also so that he can assist in that program.\nNow, I would agree that those are -- are additional arguments and they don't -- they don't strike at the construction of the statute but you go right back to the Murray case when you are worrying about how to construe this statute.\nAnd it seems to me that you find the answer in the decision of that Court -- of this Court in the Murray case.\nFor these reasons, I respectfully submit that the decision and judgment of the Court of Appeals for the Eighth Circuit should be affirmed.",
#      'start_times': [2242.546,
#       2248.246,
#       2256.996,
#       2283.917,
#       2302.077,
#       2313.704,
#       2326.878,
#       2336.352,
#       2345.775,
#       2356.795,
#       2370.43,
#       2378.52],
#      'stop_times': [2248.246,
#       2256.996,
#       2283.917,
#       2302.077,
#       2313.704,
#       2326.878,
#       2336.352,
#       2345.775,
#       2356.795,
#       2370.43,
#       2378.52,
#       2386.759]},
#     {'speaker_id': 'j__earl_warren',
#      'text': 'Mr. Murphy.',
#      'start_times': [2386.759],
#      'stop_times': [2388.055]},
#     {'speaker_id': 'harry_f_murphy',
#      'text': 'If the Court please, I see that I can add nothing to what I have said previously.\nI think the decision of this Court will go a long ways towards turning up a misunderstanding that exist throughout the country because we have District Courts and unreported cases which we know about or not daily but frequently suspending the execution of sentences yet to be served where the defendants is confined.\nWe have the conflict between the Ninth and Tenth Circuits on the one hand and the Eighth and Fourth on the other.\nSo with regard to the outcome of the -- the decision of this Court, I think it will be helpful -- future administration of judgments.',
#      'start_times': [2388.055, 2395.337, 2416.061, 2421.446],
#      'stop_times': [2395.337, 2416.061, 2421.446, 2431.978]}]],
#   'case_id': '1955_71',
#   'votes_side': {'j__john_m_harlan2': 0,
#    'j__hugo_l_black': 0,
#    'j__william_o_douglas': 0,
#    'j__earl_warren': 0,
#    'j__tom_c_clark': 0,
#    'j__felix_frankfurter': 0,
#    'j__harold_burton': 0,
#    'j__stanley_reed': 0,
#    'j__sherman_minton': 0},
#   'favor_side': 0},
#  'oyez_summary': {'Facts of the case': [], 'Question': [], 'Conclusion': []},
#  'justia_summary': {'opinion_summary': [], 'primary_holding': []},
#  'wikipedia_summary': [],
#  'companion_cases': False}

# %%
superscotus_to_scdb_id = {}
for row in superscotus:
    if row["year"] >=1986:
        superscotus_to_scdb_id[row["id"]] = row["scdb_elements"]["caseId"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 4
#       2 for row in superscotus:
#       3     if row["year"] >=1986:
# ----> 4         superscotus_to_scdb_id[row["id"]] = row["scdb_elements"]["caseId"]
#
# KeyError: 'scdb_elements'

# %%
superscotus_cases_by_year = defaultdict(set)
for row in superscotus:
    if row["year"] >= 1986:
        superscotus_cases_by_year[row["year"]].add(row["docket_no"])
superscotus_year_counts = {k: len(v) for k, v in superscotus_cases_by_year.items()}

# %%
superscotus_year_counts = Counter([row["year"] for row in superscotus if row["year"] >=1986])
sorted(superscotus_year_counts.items())
# Out:
# [(1986, 146),
#  (1987, 142),
#  (1988, 136),
#  (1989, 127),
#  (1990, 115),
#  (1991, 108),
#  (1992, 106),
#  (1993, 82),
#  (1994, 80),
#  (1995, 76),
#  (1996, 81),
#  (1997, 93),
#  (1998, 79),
#  (1999, 74),
#  (2000, 77),
#  (2001, 77),
#  (2002, 76),
#  (2003, 75),
#  (2004, 75),
#  (2005, 75),
#  (2006, 71),
#  (2007, 69),
#  (2008, 78),
#  (2009, 77),
#  (2010, 78),
#  (2011, 68),
#  (2012, 73),
#  (2013, 66),
#  (2014, 53),
#  (2015, 68),
#  (2016, 62),
#  (2017, 63),
#  (2018, 70),
#  (2019, 58)]

# %%
scdb = pd.read_csv("data/scdb/SCDB_2023_01_justiceCentered_Docket.csv", encoding="cp1252")
scdb_86_onward = scdb[(scdb.term >= 1986) & (scdb.term <= 2019)]

# %%
scdb_cases_by_term = defaultdict(set)
for i, row in scdb_86_onward.iterrows():
    scdb_cases_by_term[row["term"]].add(row.docket)
scdb_year_counts = {k: len(v) for k, v in scdb_cases_by_term.items()}

# %%
scdb_year_counts
# Out:
# {1986: 182,
#  1987: 165,
#  1988: 177,
#  1989: 154,
#  1990: 140,
#  1991: 149,
#  1992: 125,
#  1993: 123,
#  1994: 101,
#  1995: 106,
#  1996: 106,
#  1997: 108,
#  1998: 104,
#  1999: 92,
#  2000: 94,
#  2001: 95,
#  2002: 92,
#  2003: 95,
#  2004: 91,
#  2005: 100,
#  2006: 84,
#  2007: 80,
#  2008: 94,
#  2009: 96,
#  2010: 94,
#  2011: 88,
#  2012: 82,
#  2013: 85,
#  2014: 83,
#  2015: 95,
#  2016: 76,
#  2017: 80,
#  2018: 76,
#  2019: 76}

# %%
sum([1 for row in superscotus if row["year"] >=1986])
# Out:
# 2854

# %%
list(superscotus_cases_by_year[2014])[:10]
# Out:
# ['14-15',
#  '13-485',
#  '13-553',
#  '14-6368',
#  '13-1032',
#  '14-7955',
#  '13-1175',
#  '13-1041',
#  '13-433',
#  '14-114']

# %%
pd.set_option('display.max_columns', None)

# %%
display(scdb_86_onward[scdb_86_onward["docket"] == "13-895"])
# Out:
#          caseId     docketId    caseIssuesId                voteId  \
# 89827  2014-017  2014-017-01  2014-017-01-01  2014-017-01-01-01-01
# 89828  2014-017  2014-017-01  2014-017-01-01  2014-017-01-01-01-02
# 89829  2014-017  2014-017-01  2014-017-01-01  2014-017-01-01-01-03
# 89830  2014-017  2014-017-01  2014-017-01-01  2014-017-01-01-01-04
# 89831  2014-017  2014-017-01  2014-017-01-01  2014-017-01-01-01-05
# 89832  2014-017  2014-017-01  2014-017-01-01  2014-017-01-01-01-06
# 89833  2014-017  2014-017-01  2014-017-01-01  2014-017-01-01-01-07
# 89834  2014-017  2014-017-01  2014-017-01-01  2014-017-01-01-01-08
# 89835  2014-017  2014-017-01  2014-017-01-01  2014-017-01-01-01-09
#
#       dateDecision  decisionType        usCite          sctCite  \
# 89827    3/25/2015             1  575 U.S. 254  135 S. Ct. 1257
# 89828    3/25/2015             1  575 U.S. 254  135 S. Ct. 1257
# 89829    3/25/2015             1  575 U.S. 254  135 S. Ct. 1257
# 89830    3/25/2015             1  575 U.S. 254  135 S. Ct. 1257
# 89831    3/25/2015             1  575 U.S. 254  135 S. Ct. 1257
# 89832    3/25/2015             1  575 U.S. 254  135 S. Ct. 1257
# 89833    3/25/2015             1  575 U.S. 254  135 S. Ct. 1257
# 89834    3/25/2015             1  575 U.S. 254  135 S. Ct. 1257
# 89835    3/25/2015             1  575 U.S. 254  135 S. Ct. 1257
#
#                  ledCite             lexisCite  term  naturalCourt    chief  \
# 89827  191 L. Ed. 2d 314  2015 U.S. LEXIS 2122  2014          1704  Roberts
# 89828  191 L. Ed. 2d 314  2015 U.S. LEXIS 2122  2014          1704  Roberts
# 89829  191 L. Ed. 2d 314  2015 U.S. LEXIS 2122  2014          1704  Roberts
# 89830  191 L. Ed. 2d 314  2015 U.S. LEXIS 2122  2014          1704  Roberts
# 89831  191 L. Ed. 2d 314  2015 U.S. LEXIS 2122  2014          1704  Roberts
# 89832  191 L. Ed. 2d 314  2015 U.S. LEXIS 2122  2014          1704  Roberts
# 89833  191 L. Ed. 2d 314  2015 U.S. LEXIS 2122  2014          1704  Roberts
# 89834  191 L. Ed. 2d 314  2015 U.S. LEXIS 2122  2014          1704  Roberts
# 89835  191 L. Ed. 2d 314  2015 U.S. LEXIS 2122  2014          1704  Roberts
#
#        docket                                  caseName dateArgument  \
# 89827  13-895  ALA. LEGISLATIVE BLACK CAUCUS v. ALABAMA   11/12/2014
# 89828  13-895  ALA. LEGISLATIVE BLACK CAUCUS v. ALABAMA   11/12/2014
# 89829  13-895  ALA. LEGISLATIVE BLACK CAUCUS v. ALABAMA   11/12/2014
# 89830  13-895  ALA. LEGISLATIVE BLACK CAUCUS v. ALABAMA   11/12/2014
# 89831  13-895  ALA. LEGISLATIVE BLACK CAUCUS v. ALABAMA   11/12/2014
# 89832  13-895  ALA. LEGISLATIVE BLACK CAUCUS v. ALABAMA   11/12/2014
# 89833  13-895  ALA. LEGISLATIVE BLACK CAUCUS v. ALABAMA   11/12/2014
# 89834  13-895  ALA. LEGISLATIVE BLACK CAUCUS v. ALABAMA   11/12/2014
# 89835  13-895  ALA. LEGISLATIVE BLACK CAUCUS v. ALABAMA   11/12/2014
#
#       dateRearg  petitioner  petitionerState  respondent  respondentState  \
# 89827       NaN        19.0              1.0        28.0              1.0
# 89828       NaN        19.0              1.0        28.0              1.0
# 89829       NaN        19.0              1.0        28.0              1.0
# 89830       NaN        19.0              1.0        28.0              1.0
# 89831       NaN        19.0              1.0        28.0              1.0
# 89832       NaN        19.0              1.0        28.0              1.0
# 89833       NaN        19.0              1.0        28.0              1.0
# 89834       NaN        19.0              1.0        28.0              1.0
# 89835       NaN        19.0              1.0        28.0              1.0
#
#        jurisdiction  adminAction  adminActionState  threeJudgeFdc  caseOrigin  \
# 89827           2.0          NaN               NaN            1.0        41.0
# 89828           2.0          NaN               NaN            1.0        41.0
# 89829           2.0          NaN               NaN            1.0        41.0
# 89830           2.0          NaN               NaN            1.0        41.0
# 89831           2.0          NaN               NaN            1.0        41.0
# 89832           2.0          NaN               NaN            1.0        41.0
# 89833           2.0          NaN               NaN            1.0        41.0
# 89834           2.0          NaN               NaN            1.0        41.0
# 89835           2.0          NaN               NaN            1.0        41.0
#
#        caseOriginState  caseSource  caseSourceState  lcDisagreement  \
# 89827              NaN        41.0              NaN             1.0
# 89828              NaN        41.0              NaN             1.0
# 89829              NaN        41.0              NaN             1.0
# 89830              NaN        41.0              NaN             1.0
# 89831              NaN        41.0              NaN             1.0
# 89832              NaN        41.0              NaN             1.0
# 89833              NaN        41.0              NaN             1.0
# 89834              NaN        41.0              NaN             1.0
# 89835              NaN        41.0              NaN             1.0
#
#        certReason  lcDisposition  lcDispositionDirection  declarationUncon  \
# 89827         1.0            NaN                     1.0               1.0
# 89828         1.0            NaN                     1.0               1.0
# 89829         1.0            NaN                     1.0               1.0
# 89830         1.0            NaN                     1.0               1.0
# 89831         1.0            NaN                     1.0               1.0
# 89832         1.0            NaN                     1.0               1.0
# 89833         1.0            NaN                     1.0               1.0
# 89834         1.0            NaN                     1.0               1.0
# 89835         1.0            NaN                     1.0               1.0
#
#        caseDisposition  caseDispositionUnusual  partyWinning  \
# 89827              5.0                     0.0           1.0
# 89828              5.0                     0.0           1.0
# 89829              5.0                     0.0           1.0
# 89830              5.0                     0.0           1.0
# 89831              5.0                     0.0           1.0
# 89832              5.0                     0.0           1.0
# 89833              5.0                     0.0           1.0
# 89834              5.0                     0.0           1.0
# 89835              5.0                     0.0           1.0
#
#        precedentAlteration  voteUnclear    issue  issueArea  \
# 89827                  0.0          0.0  20090.0        2.0
# 89828                  0.0          0.0  20090.0        2.0
# 89829                  0.0          0.0  20090.0        2.0
# 89830                  0.0          0.0  20090.0        2.0
# 89831                  0.0          0.0  20090.0        2.0
# 89832                  0.0          0.0  20090.0        2.0
# 89833                  0.0          0.0  20090.0        2.0
# 89834                  0.0          0.0  20090.0        2.0
# 89835                  0.0          0.0  20090.0        2.0
#
#        decisionDirection  decisionDirectionDissent  authorityDecision1  \
# 89827                2.0                       0.0                 1.0
# 89828                2.0                       0.0                 1.0
# 89829                2.0                       0.0                 1.0
# 89830                2.0                       0.0                 1.0
# 89831                2.0                       0.0                 1.0
# 89832                2.0                       0.0                 1.0
# 89833                2.0                       0.0                 1.0
# 89834                2.0                       0.0                 1.0
# 89835                2.0                       0.0                 1.0
#
#        authorityDecision2  lawType  lawSupp lawMinor  majOpinWriter  \
# 89827                 NaN      2.0    231.0      NaN          110.0
# 89828                 NaN      2.0    231.0      NaN          110.0
# 89829                 NaN      2.0    231.0      NaN          110.0
# 89830                 NaN      2.0    231.0      NaN          110.0
# 89831                 NaN      2.0    231.0      NaN          110.0
# 89832                 NaN      2.0    231.0      NaN          110.0
# 89833                 NaN      2.0    231.0      NaN          110.0
# 89834                 NaN      2.0    231.0      NaN          110.0
# 89835                 NaN      2.0    231.0      NaN          110.0
#
#        majOpinAssigner  splitVote  majVotes  minVotes  justice justiceName  \
# 89827            106.0          1         5         4      111   JGRoberts
# 89828            106.0          1         5         4      105     AScalia
# 89829            106.0          1         5         4      106   AMKennedy
# 89830            106.0          1         5         4      108     CThomas
# 89831            106.0          1         5         4      109  RBGinsburg
# 89832            106.0          1         5         4      110    SGBreyer
# 89833            106.0          1         5         4      112     SAAlito
# 89834            106.0          1         5         4      113  SSotomayor
# 89835            106.0          1         5         4      114      EKagan
#
#        vote  opinion  direction  majority  firstAgreement  secondAgreement
# 89827   2.0      1.0        1.0       1.0           105.0              NaN
# 89828   2.0      2.0        1.0       1.0             NaN              NaN
# 89829   1.0      1.0        2.0       2.0             NaN              NaN
# 89830   2.0      2.0        1.0       1.0           105.0              NaN
# 89831   1.0      1.0        2.0       2.0             NaN              NaN
# 89832   1.0      2.0        2.0       2.0             NaN              NaN
# 89833   2.0      1.0        1.0       1.0           105.0              NaN
# 89834   1.0      1.0        2.0       2.0             NaN              NaN
# 89835   1.0      1.0        2.0       2.0             NaN              NaN

# %%
display(scdb_86_onward[scdb_86_onward["docket"] == "13-1138"])

# %%
scdb_86_onward[scdb_86_onward["usCite"] == "575 U.S. 600"]

# %% [markdown]
# https://www.oyez.org/cases/2014/13-1433 not in super-scotus but https://www.oyez.org/cases/2014/14-7955 (which looks very similar) is

# %%
"13-1421" in convokit_ids
# Out:
# True

# %% [markdown]
# '126, ORIG.', original docket
#  '13-1052', consolidated
#  '13-1075', consolidated
#  '13-1138', consolidated
#  '13-1412', SF vs Sheehan MISSING
#  '13-1421', BOA v Caulkett MISSING
#  '13-1433', Brumfield v cain MISSING
#  '13-534',
#  '13-720',
#  '13-7211',
#  '13-896',
#  '13-946',
#  '13–1318',
#  '14-116',
#  '14-163',
#  '14-212',
#  '14-275',
#  '14-378',
#  '14-400',
#  '14-46',
#  '14-47',
#  '14-49',
#  '14-562',
#  '14-571',
#  '14-574',
#  '14-593',
#  '14-618',
#  '14-6873',
#  '14-939',
#  '14–95'

# %%
# Cases that are in SCDB that aren't in superscotus
scdb_cases_by_term[2014].difference(superscotus_cases_by_year[2014])
# Out:
# {'126, ORIG.',
#  '13-1052',
#  '13-1075',
#  '13-1138',
#  '13-1412',
#  '13-1421',
#  '13-1433',
#  '13-534',
#  '13-720',
#  '13-7211',
#  '13-896',
#  '13-946',
#  '13–1318',
#  '14-116',
#  '14-163',
#  '14-212',
#  '14-275',
#  '14-378',
#  '14-400',
#  '14-46',
#  '14-47',
#  '14-49',
#  '14-562',
#  '14-571',
#  '14-574',
#  '14-593',
#  '14-618',
#  '14-6873',
#  '14-939',
#  '14–95'}

# %%
# Cases that are in ConvoKit but not in Super-SCOTUS
missing = Counter()
for year, docket_numbers in scdb_cases_by_term.items():
    for d in docket_numbers:
        if d not in superscotus_cases_by_year[year]:
            if d in convokit_ids:
                missing[year] += 1

sorted(missing.items())

# %%
pd.DataFrame(zip(superscotus_year_counts.values(), scdb_year_counts.values()),
             columns=["Super-SCOTUS", "SCDB"], index=superscotus_year_counts.keys())
